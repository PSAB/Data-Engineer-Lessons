# %% [markdown]
# ## Data Wrangling with Pyspark: Data Error

# %%
from pyspark.sql import SparkSession
from pyspark.context import SparkContext

# %%
spark = SparkSession.builder \
        .appName("Spark Data Wrangling Issue") \
        .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.0.2.15:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark Data Wrangling Issue</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
path = "spark_data/sparkify_log_small_error.json"
logs = spark.read.json(path)

# %%
logs.head(2)
# Out:
# [Row(_corrupt_record=None, artist='Showaddywaddy', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=112, lastName='Matthews', length=232.93342, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='Christmas Tears Will Fall', status=200, ts=1513720872284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046'),
#  Row(_corrupt_record=None, artist='Lily Allen', auth='Logged In', firstName='Elizabeth', gender='F', itemInSession=7, lastName='Chase', length=195.23873, level='free', location='Shreveport-Bossier City, LA', method='PUT', page='NextSong', registration=1512718541284, sessionId=5027, song='Cheryl Tweedy', status=200, ts=1513720878284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1000')]

# %% [markdown]
# As we can see, a new field ```_corrupt_record``` has appeared. In the 2 records above, its value is ```None```, so let's try to find a corrupt record:

# %%
logs.where(logs["_corrupt_record"].isNotNull()).collect()
# Out:
# [Row(_corrupt_record='{"ts":1513720980284,"userId":597dude,"sessionId":3689,"page":"Home","auth":"Logged In","method":"GET","status":200,"level":"free","itemInSession":0,"location":"Green Bay, WI","userAgent":"\\"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36\\"","lastName":"Short","firstName":"Alexander","registration":1513594398284,"gender":"M"}', artist=None, auth=None, firstName=None, gender=None, itemInSession=None, lastName=None, length=None, level=None, location=None, method=None, page=None, registration=None, sessionId=None, song=None, status=None, ts=None, userAgent=None, userId=None)]

# %% [markdown]
# It looks like the value for ```userId``` is throwing an error, so it couldn't be read. When the Value for ```_corrupt_record``` is filled, it points to the values of the record that triggered such an error, and all other fields are ```None```

# %%
# Let's define an accumulator:
incorrect_records = SparkContext.accumulator(0, 0)

# %%
incorrect_records
# Out:
# Accumulator<id=0, value=0>

# %%
type(incorrect_records)
# Out:
# pyspark.accumulators.Accumulator

# %%
incorrect_records.value
# Out:
# 0

# %%
# Create a function to increment accumulator:
def add_incorrect_record():
    global incorrect_records
    incorrect_records += 1

# %%
# Create a UDF that we can apply to the DataFrame and check the userId values in each row
from pyspark.sql.functions import udf
correct_userId = udf(lambda x: 1 if x.isdigit() else add_incorrect_record())

# %%
# Let's add a new column userId_digit to logs by applying the correct_userId function to the userID column in logs:
logs = logs.where(logs["_corrupt_record"].isNull()).withColumn("userId_digit", correct_userId(logs.userId))

# %%
incorrect_records.value
# Out:
# 0

# %% [markdown]
# Due to Lazy Evaluation, the ```logs``` DataFrame hasn't changed yet. Let's force the change using ```collect()```:

# %%
logs.collect()
# Out:
# [Row(_corrupt_record=None, artist='Showaddywaddy', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=112, lastName='Matthews', length=232.93342, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='Christmas Tears Will Fall', status=200, ts=1513720872284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Lily Allen', auth='Logged In', firstName='Elizabeth', gender='F', itemInSession=7, lastName='Chase', length=195.23873, level='free', location='Shreveport-Bossier City, LA', method='PUT', page='NextSong', registration=1512718541284, sessionId=5027, song='Cheryl Tweedy', status=200, ts=1513720878284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1000', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Cobra Starship Featuring Leighton Meester', auth='Logged In', firstName='Vera', gender='F', itemInSession=6, lastName='Blackwell', length=196.20526, level='paid', location='Racine, WI', method='PUT', page='NextSong', registration=1499855749284, sessionId=5516, song='Good Girls Go Bad (Feat.Leighton Meester) (Album Version)', status=200, ts=1513720881284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"', userId='2219', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Alex Smoke', auth='Logged In', firstName='Sophee', gender='F', itemInSession=8, lastName='Barker', length=405.99465, level='paid', location='San Luis Obispo-Paso Robles-Arroyo Grande, CA', method='PUT', page='NextSong', registration=1513009647284, sessionId=2372, song="Don't See The Point", status=200, ts=1513720905284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2373', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Jordyn', gender='F', itemInSession=0, lastName='Jones', length=None, level='free', location='Syracuse, NY', method='GET', page='Home', registration=1513648531284, sessionId=1746, song=None, status=200, ts=1513720913284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"', userId='1747', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Jordyn', gender='F', itemInSession=1, lastName='Jones', length=None, level='free', location='Syracuse, NY', method='GET', page='Settings', registration=1513648531284, sessionId=1746, song=None, status=200, ts=1513720932284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"', userId='1747', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Redman', auth='Logged In', firstName='Paige', gender='F', itemInSession=0, lastName='Hunter', length=154.53995, level='free', location='Brownwood, TX', method='PUT', page='NextSong', registration=1498414068284, sessionId=4406, song='Smoke Buddah', status=200, ts=1513720955284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"', userId='1162', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Ulrich Schnauss', auth='Logged In', firstName='Gabriel', gender='M', itemInSession=2, lastName='Koch', length=402.93832, level='paid', location='Panama City, FL', method='PUT', page='NextSong', registration=1505820418284, sessionId=1060, song='On My Own', status=200, ts=1513720959284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0', userId='1061', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Mason', gender='M', itemInSession=2, lastName='Thomas', length=None, level='paid', location='Indianapolis-Carmel-Anderson, IN', method='GET', page='Home', registration=1487015656284, sessionId=5661, song=None, status=200, ts=1513720959284, userAgent='Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)', userId='748', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Jay-Z', auth='Logged In', firstName='Micheal', gender='M', itemInSession=23, lastName='Morgan', length=223.26812, level='paid', location='Sterling, CO', method='PUT', page='NextSong', registration=1485051492284, sessionId=5175, song="Heart Of The City (Ain't No Love)", status=200, ts=1513720983284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1806', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Evanescence', auth='Logged In', firstName='Mason', gender='M', itemInSession=3, lastName='Thomas', length=237.11302, level='paid', location='Indianapolis-Carmel-Anderson, IN', method='PUT', page='NextSong', registration=1487015656284, sessionId=5661, song='Bring Me To Life', status=200, ts=1513720993284, userAgent='Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)', userId='748', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Scissor Sisters', auth='Logged In', firstName='Justin', gender='M', itemInSession=82, lastName='Jones', length=218.01751, level='paid', location='Dayton, TN', method='PUT', page='NextSong', registration=1504706730284, sessionId=1175, song='Laura', status=200, ts=1513721031284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1176', userId_digit='1'),
#  Row(_corrupt_record=None, artist='3 Doors Down', auth='Logged In', firstName='Zoie', gender='F', itemInSession=28, lastName='Wright', length=237.13914, level='paid', location='Chicago-Naperville-Elgin, IL-IN-WI', method='PUT', page='NextSong', registration=1512172030284, sessionId=2163, song='Here Without You', status=200, ts=1513721045284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2164', userId_digit='1'),
#  Row(_corrupt_record=None, artist='George Younce', auth='Logged In', firstName='Malachi', gender='M', itemInSession=3, lastName='Lane', length=191.68608, level='free', location='Sioux Falls, SD', method='PUT', page='NextSong', registration=1510109243284, sessionId=5272, song='This Old House w/ When The Saints Medley', status=200, ts=1513721058284, userAgent='Mozilla/5.0 (Windows NT 6.2; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='2146', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Aly-Us', auth='Logged In', firstName='Vera', gender='F', itemInSession=7, lastName='Blackwell', length=383.58159, level='paid', location='Racine, WI', method='PUT', page='NextSong', registration=1499855749284, sessionId=5516, song='Follow Me (Club Mix)', status=200, ts=1513721077284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"', userId='2219', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Justin', gender='M', itemInSession=83, lastName='Jones', length=None, level='paid', location='Dayton, TN', method='GET', page='Home', registration=1504706730284, sessionId=1175, song=None, status=200, ts=1513721088284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1176', userId_digit='1'),
#  Row(_corrupt_record=None, artist='BjÃ\x83Â¶rk', auth='Logged In', firstName='Elena', gender='F', itemInSession=0, lastName='Newman', length=348.57751, level='free', location='Boston-Cambridge-Newton, MA-NH', method='PUT', page='NextSong', registration=1513494341284, sessionId=2903, song='Undo', status=200, ts=1513721095284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='2904', userId_digit='1'),
#  Row(_corrupt_record=None, artist='David Bromberg', auth='Logged In', firstName='Alexander', gender='M', itemInSession=1, lastName='Short', length=146.36363, level='free', location='Green Bay, WI', method='PUT', page='NextSong', registration=1513594398284, sessionId=3689, song='Sheebeg And Sheemore', status=200, ts=1513721097284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='597', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Nickelback', auth='Logged In', firstName='Abigail', gender='F', itemInSession=4, lastName='Davidson', length=238.18404, level='paid', location='Lansing-East Lansing, MI', method='PUT', page='NextSong', registration=1513173389284, sessionId=4591, song='Far Away (Album Version)', status=200, ts=1513721104284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"', userId='226', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Darius Rucker', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=113, lastName='Matthews', length=206.00118, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='Be Wary Of A Woman', status=200, ts=1513721104284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Mayday Parade', auth='Logged In', firstName='Paige', gender='F', itemInSession=1, lastName='Hunter', length=241.42322, level='free', location='Brownwood, TX', method='PUT', page='NextSong', registration=1498414068284, sessionId=4406, song="I'd Hate To Be You When People Find Out What This Song Is About (Album)", status=200, ts=1513721109284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"', userId='1162', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Simple Minds', auth='Logged In', firstName='Ryder', gender='M', itemInSession=1, lastName='Rodriguez', length=401.78893, level='free', location='Freeport, IL', method='PUT', page='NextSong', registration=1513668346284, sessionId=2941, song='Oh Jungleland', status=200, ts=1513721127284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2942', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Justin', gender='M', itemInSession=84, lastName='Jones', length=None, level='paid', location='Dayton, TN', method='GET', page='Settings', registration=1504706730284, sessionId=1175, song=None, status=200, ts=1513721160284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1176', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Dropkick Murphys', auth='Logged In', firstName='Eliana', gender='F', itemInSession=1, lastName='Thomas', length=159.76444, level='paid', location='Knoxville, TN', method='PUT', page='NextSong', registration=1511496362284, sessionId=4686, song="Captain Kelly's Kitchen", status=200, ts=1513721182284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2779', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5598, song=None, status=307, ts=1513721196284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist='Milczenie Owiec', auth='Logged In', firstName='Micheal', gender='M', itemInSession=24, lastName='Morgan', length=219.29751, level='paid', location='Sterling, CO', method='PUT', page='NextSong', registration=1485051492284, sessionId=5175, song='CIEÃ\x83Â\x91', status=200, ts=1513721206284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1806', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Jonny Lang', auth='Logged In', firstName='Lillian', gender='F', itemInSession=2, lastName='Ryan', length=226.2722, level='free', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1510762899284, sessionId=4641, song='Red Light', status=200, ts=1513721207284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2887', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Nicole C. Mullen', auth='Logged In', firstName='Connor', gender='M', itemInSession=18, lastName='Gillespie', length=282.90567, level='paid', location='Santa Cruz-Watsonville, CA', method='PUT', page='NextSong', registration=1506639389284, sessionId=5698, song='Without You (LP Version)', status=200, ts=1513721214284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1035', userId_digit='1'),
#  Row(_corrupt_record=None, artist='The Police', auth='Logged In', firstName='Mason', gender='M', itemInSession=4, lastName='Thomas', length=289.2273, level='paid', location='Indianapolis-Carmel-Anderson, IN', method='PUT', page='NextSong', registration=1487015656284, sessionId=5661, song='Message In A Bottle', status=200, ts=1513721230284, userAgent='Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)', userId='748', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Carla Bruni', auth='Logged In', firstName='Alexander', gender='M', itemInSession=2, lastName='Short', length=163.02975, level='free', location='Green Bay, WI', method='PUT', page='NextSong', registration=1513594398284, sessionId=3689, song="Quelqu'un M'a Dit (Album Version)", status=200, ts=1513721243284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='597', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Caitlin', gender='F', itemInSession=1, lastName='Payne', length=None, level='free', location='Atlanta-Sandy Springs-Roswell, GA', method='GET', page='Home', registration=1510779804284, sessionId=5598, song=None, status=200, ts=1513721247284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='577', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Biffy Clyro', auth='Logged In', firstName='Justin', gender='M', itemInSession=85, lastName='Jones', length=301.08689, level='paid', location='Dayton, TN', method='PUT', page='NextSong', registration=1504706730284, sessionId=1175, song='Bubbles', status=200, ts=1513721249284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1176', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Labi Siffre', auth='Logged In', firstName='Cesar', gender='M', itemInSession=24, lastName='Johnson', length=244.81914, level='paid', location='San Antonio-New Braunfels, TX', method='PUT', page='NextSong', registration=1513431505284, sessionId=428, song='Entertainment Value (2006 Digital Remaster)', status=200, ts=1513721266284, userAgent='"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='429', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Cesar', gender='M', itemInSession=25, lastName='Johnson', length=None, level='paid', location='San Antonio-New Braunfels, TX', method='PUT', page='Logout', registration=1513431505284, sessionId=428, song=None, status=307, ts=1513721267284, userAgent='"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='429', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=26, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=428, song=None, status=200, ts=1513721274284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Adam', gender='M', itemInSession=0, lastName='Silva', length=None, level='free', location='Philadelphia-Camden-Wilmington, PA-NJ-DE-MD', method='GET', page='Home', registration=1513049878284, sessionId=5355, song=None, status=200, ts=1513721278284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='88', userId_digit='1'),
#  Row(_corrupt_record=None, artist='3OH!3', auth='Logged In', firstName='Zoie', gender='F', itemInSession=29, lastName='Wright', length=196.28363, level='paid', location='Chicago-Naperville-Elgin, IL-IN-WI', method='PUT', page='NextSong', registration=1512172030284, sessionId=2163, song='DONTTRUSTME [BENNYBLANCOREMIX] FEATURINGKIDCUDI (Explicit Bonus Version)', status=200, ts=1513721282284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2164', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Poe', auth='Logged In', firstName='Sophee', gender='F', itemInSession=9, lastName='Barker', length=320.05179, level='paid', location='San Luis Obispo-Paso Robles-Arroyo Grande, CA', method='PUT', page='NextSong', registration=1513009647284, sessionId=2372, song='Haunted', status=200, ts=1513721310284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2373', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Public Enemy', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=114, lastName='Matthews', length=281.05098, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='Public Enemy No.1', status=200, ts=1513721310284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Lucas', gender='F', itemInSession=0, lastName='Hodges', length=None, level='free', location='Tupelo, MS', method='GET', page='Home', registration=1483819940284, sessionId=2084, song=None, status=200, ts=1513721321284, userAgent='"Mozilla/5.0 (iPad; CPU OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='2085', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Deadmau5', auth='Logged In', firstName='Caitlin', gender='F', itemInSession=2, lastName='Payne', length=374.20363, level='free', location='Atlanta-Sandy Springs-Roswell, GA', method='PUT', page='NextSong', registration=1510779804284, sessionId=5598, song="Ghosts 'n' Stuff (Original Instrumental Mix)", status=200, ts=1513721328284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='577', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Leonard Cohen', auth='Logged In', firstName='Eliana', gender='F', itemInSession=2, lastName='Thomas', length=153.46893, level='paid', location='Knoxville, TN', method='PUT', page='NextSong', registration=1511496362284, sessionId=4686, song='Who By Fire', status=200, ts=1513721341284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2779', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Justin Bieber', auth='Logged In', firstName='Abigail', gender='F', itemInSession=5, lastName='Davidson', length=212.53179, level='paid', location='Lansing-East Lansing, MI', method='PUT', page='NextSong', registration=1513173389284, sessionId=4591, song='Runaway Love', status=200, ts=1513721342284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"', userId='226', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Justin Bieber', auth='Logged In', firstName='Gabriel', gender='M', itemInSession=3, lastName='Koch', length=222.92853, level='paid', location='Panama City, FL', method='PUT', page='NextSong', registration=1505820418284, sessionId=1060, song='Stuck In The Moment', status=200, ts=1513721361284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0', userId='1061', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Vox Dei', auth='Logged In', firstName='Lucas', gender='F', itemInSession=1, lastName='Hodges', length=137.27302, level='free', location='Tupelo, MS', method='PUT', page='NextSong', registration=1483819940284, sessionId=2084, song='Libros Sapienciales', status=200, ts=1513721376284, userAgent='"Mozilla/5.0 (iPad; CPU OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='2085', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Coheed and Cambria', auth='Logged In', firstName='Micheal', gender='M', itemInSession=25, lastName='Morgan', length=300.64281, level='paid', location='Sterling, CO', method='PUT', page='NextSong', registration=1485051492284, sessionId=5175, song='Cuts Marked In The March Of Men', status=200, ts=1513721425284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1806', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Agoria', auth='Logged In', firstName='Lillian', gender='F', itemInSession=3, lastName='Ryan', length=396.09424, level='free', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1510762899284, sessionId=4641, song='La 11Eme Marche (Alexander Kowalski Remix)', status=200, ts=1513721433284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2887', userId_digit='1'),
#  Row(_corrupt_record=None, artist='The Game', auth='Logged In', firstName='Vera', gender='F', itemInSession=8, lastName='Blackwell', length=240.48281, level='paid', location='Racine, WI', method='PUT', page='NextSong', registration=1499855749284, sessionId=5516, song='Dope Boys', status=200, ts=1513721460284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"', userId='2219', userId_digit='1'),
#  Row(_corrupt_record=None, artist='The Shins', auth='Logged In', firstName='Zoie', gender='F', itemInSession=30, lastName='Wright', length=238.65424, level='paid', location='Chicago-Naperville-Elgin, IL-IN-WI', method='PUT', page='NextSong', registration=1512172030284, sessionId=2163, song='Australia (Album)', status=200, ts=1513721478284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2164', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Rickie Lee Jones', auth='Logged In', firstName='Eliana', gender='F', itemInSession=3, lastName='Thomas', length=295.05261, level='paid', location='Knoxville, TN', method='PUT', page='NextSong', registration=1511496362284, sessionId=4686, song='Satellites', status=200, ts=1513721494284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2779', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Martina Topley Bird', auth='Logged In', firstName='Connor', gender='M', itemInSession=19, lastName='Gillespie', length=216.37179, level='paid', location='Santa Cruz-Watsonville, CA', method='PUT', page='NextSong', registration=1506639389284, sessionId=5698, song='Valentine', status=200, ts=1513721496284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1035', userId_digit='1'),
#  Row(_corrupt_record=None, artist='The Buggles', auth='Logged In', firstName='Mason', gender='M', itemInSession=5, lastName='Thomas', length=198.08608, level='paid', location='Indianapolis-Carmel-Anderson, IN', method='PUT', page='NextSong', registration=1487015656284, sessionId=5661, song='Video Killed The Radio Star', status=200, ts=1513721519284, userAgent='Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)', userId='748', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Radney Foster', auth='Logged In', firstName='Ryder', gender='M', itemInSession=2, lastName='Rodriguez', length=288.96608, level='free', location='Freeport, IL', method='PUT', page='NextSong', registration=1513668346284, sessionId=2941, song='Sweet And Wild', status=200, ts=1513721528284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2942', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Whitesnake', auth='Logged In', firstName='Justin', gender='M', itemInSession=86, lastName='Jones', length=335.77751, level='paid', location='Dayton, TN', method='PUT', page='NextSong', registration=1504706730284, sessionId=1175, song='Crying In The Rain (1987 Version) (2007 Digital Remaster)', status=200, ts=1513721550284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1176', userId_digit='1'),
#  Row(_corrupt_record=None, artist='The Rocket Summer', auth='Logged In', firstName='Abigail', gender='F', itemInSession=6, lastName='Davidson', length=227.65669, level='paid', location='Lansing-East Lansing, MI', method='PUT', page='NextSong', registration=1513173389284, sessionId=4591, song='Brat Pack', status=200, ts=1513721554284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"', userId='226', userId_digit='1'),
#  Row(_corrupt_record=None, artist='B.o.B', auth='Logged In', firstName='Gabriel', gender='M', itemInSession=4, lastName='Koch', length=269.63546, level='paid', location='Panama City, FL', method='PUT', page='NextSong', registration=1505820418284, sessionId=1060, song="Nothin' On You [feat. Bruno Mars] (Album Version)", status=200, ts=1513721583284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0', userId='1061', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Jag Panzer', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=115, lastName='Matthews', length=217.99138, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='Reign Of The Tyrants', status=200, ts=1513721591284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046', userId_digit='1'),
#  Row(_corrupt_record=None, artist='The Asteroids Galaxy Tour', auth='Logged In', firstName='Sophee', gender='F', itemInSession=10, lastName='Barker', length=228.20526, level='paid', location='San Luis Obispo-Paso Robles-Arroyo Grande, CA', method='PUT', page='NextSong', registration=1513009647284, sessionId=2372, song='Around The Bend', status=200, ts=1513721630284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2373', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Jonah', gender='M', itemInSession=0, lastName='Harding', length=None, level='free', location='San Diego-Carlsbad, CA', method='GET', page='Home', registration=1512586869284, sessionId=4038, song=None, status=200, ts=1513721646284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0', userId='1847', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Raylen', gender='F', itemInSession=0, lastName='Garcia', length=None, level='free', location='Knoxville, TN', method='GET', page='Home', registration=1509970400284, sessionId=1817, song=None, status=200, ts=1513721648284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='1818', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Deathstars', auth='Logged In', firstName='Vera', gender='F', itemInSession=9, lastName='Blackwell', length=233.9522, level='paid', location='Racine, WI', method='PUT', page='NextSong', registration=1499855749284, sessionId=5516, song='Cyanide', status=200, ts=1513721700284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"', userId='2219', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Pepper', auth='Logged In', firstName='Connor', gender='M', itemInSession=20, lastName='Gillespie', length=166.32118, level='paid', location='Santa Cruz-Watsonville, CA', method='PUT', page='NextSong', registration=1506639389284, sessionId=5698, song='Slave', status=200, ts=1513721712284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1035', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Alison Krauss / Union Station', auth='Logged In', firstName='Zoie', gender='F', itemInSession=31, lastName='Wright', length=227.18649, level='paid', location='Chicago-Naperville-Elgin, IL-IN-WI', method='PUT', page='NextSong', registration=1512172030284, sessionId=2163, song='Crazy Faith', status=200, ts=1513721716284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2164', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Beastie Boys', auth='Logged In', firstName='Mason', gender='M', itemInSession=6, lastName='Thomas', length=211.722, level='paid', location='Indianapolis-Carmel-Anderson, IN', method='PUT', page='NextSong', registration=1487015656284, sessionId=5661, song='Unite (2009 Digital Remaster)', status=200, ts=1513721717284, userAgent='Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)', userId='748', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Blumentopf;Clueso', auth='Logged In', firstName='Micheal', gender='M', itemInSession=26, lastName='Morgan', length=189.28281, level='paid', location='Sterling, CO', method='PUT', page='NextSong', registration=1485051492284, sessionId=5175, song='Manajah', status=200, ts=1513721725284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1806', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Justin', gender='M', itemInSession=87, lastName='Jones', length=None, level='paid', location='Dayton, TN', method='GET', page='Downgrade', registration=1504706730284, sessionId=1175, song=None, status=200, ts=1513721730284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1176', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Foo Fighters', auth='Logged In', firstName='Abigail', gender='F', itemInSession=7, lastName='Davidson', length=271.38567, level='paid', location='Lansing-East Lansing, MI', method='PUT', page='NextSong', registration=1513173389284, sessionId=4591, song='The Pretender', status=200, ts=1513721781284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"', userId='226', userId_digit='1'),
#  Row(_corrupt_record=None, artist='B.o.B', auth='Logged In', firstName='Eliana', gender='F', itemInSession=4, lastName='Thomas', length=269.63546, level='paid', location='Knoxville, TN', method='PUT', page='NextSong', registration=1511496362284, sessionId=4686, song="Nothin' On You [feat. Bruno Mars] (Album Version)", status=200, ts=1513721789284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2779', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Boyzone', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=116, lastName='Matthews', length=168.04526, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='Father And Son', status=200, ts=1513721808284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Sick Puppies', auth='Logged In', firstName='Ryder', gender='M', itemInSession=3, lastName='Rodriguez', length=248.58077, level='free', location='Freeport, IL', method='PUT', page='NextSong', registration=1513668346284, sessionId=2941, song='What Are You Looking For', status=200, ts=1513721816284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2942', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Ryder', gender='M', itemInSession=4, lastName='Rodriguez', length=None, level='free', location='Freeport, IL', method='PUT', page='Logout', registration=1513668346284, sessionId=2941, song=None, status=307, ts=1513721817284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2942', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Peter Bjorn And John', auth='Logged In', firstName='Gabriel', gender='M', itemInSession=5, lastName='Koch', length=228.85832, level='paid', location='Panama City, FL', method='PUT', page='NextSong', registration=1505820418284, sessionId=1060, song='The Chills', status=200, ts=1513721852284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0', userId='1061', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Connor', gender='M', itemInSession=21, lastName='Gillespie', length=None, level='paid', location='Santa Cruz-Watsonville, CA', method='GET', page='Help', registration=1506639389284, sessionId=5698, song=None, status=200, ts=1513721855284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1035', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Tito Allen', auth='Logged In', firstName='Sophee', gender='F', itemInSession=11, lastName='Barker', length=298.97098, level='paid', location='San Luis Obispo-Paso Robles-Arroyo Grande, CA', method='PUT', page='NextSong', registration=1513009647284, sessionId=2372, song='Que Se Sepa', status=200, ts=1513721858284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2373', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Josh Turner', auth='Logged In', firstName='Connor', gender='M', itemInSession=22, lastName='Gillespie', length=211.85261, level='paid', location='Santa Cruz-Watsonville, CA', method='PUT', page='NextSong', registration=1506639389284, sessionId=5698, song='Your Man', status=200, ts=1513721878284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1035', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Bill Wells & Maher Shalal Hash Baz', auth='Logged In', firstName='Justin', gender='M', itemInSession=88, lastName='Jones', length=131.44771, level='paid', location='Dayton, TN', method='PUT', page='NextSong', registration=1504706730284, sessionId=1175, song='Banned Announcement', status=200, ts=1513721885284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1176', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Bloc Party', auth='Logged In', firstName='Joshua', gender='M', itemInSession=46, lastName='Blake', length=210.83383, level='paid', location='Fayetteville-Springdale-Rogers, AR-MO', method='PUT', page='NextSong', registration=1512526653284, sessionId=5340, song='Trojan Horse', status=200, ts=1513721892284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1949', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Madonna', auth='Logged In', firstName='Micheal', gender='M', itemInSession=27, lastName='Morgan', length=191.13751, level='paid', location='Sterling, CO', method='PUT', page='NextSong', registration=1485051492284, sessionId=5175, song='Like A Virgin (Edit Version)', status=200, ts=1513721914284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1806', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Talib Kweli / Mos Def', auth='Logged In', firstName='Mason', gender='M', itemInSession=7, lastName='Thomas', length=254.58893, level='paid', location='Indianapolis-Carmel-Anderson, IN', method='PUT', page='NextSong', registration=1487015656284, sessionId=5661, song='Joy', status=200, ts=1513721928284, userAgent='Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)', userId='748', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Alliance Ethnik', auth='Logged In', firstName='Vera', gender='F', itemInSession=10, lastName='Blackwell', length=195.94404, level='paid', location='Racine, WI', method='PUT', page='NextSong', registration=1499855749284, sessionId=5516, song='SinceritÃ\x83Â© Et Jalousie', status=200, ts=1513721933284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"', userId='2219', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Monster Magnet', auth='Logged In', firstName='Zoie', gender='F', itemInSession=32, lastName='Wright', length=245.13261, level='paid', location='Chicago-Naperville-Elgin, IL-IN-WI', method='PUT', page='NextSong', registration=1512172030284, sessionId=2163, song='See You In Hell', status=200, ts=1513721943284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2164', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Hollywood Undead', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=117, lastName='Matthews', length=185.20771, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='No. 5', status=200, ts=1513721976284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Chicks On Speed', auth='Logged In', firstName='Pierre', gender='M', itemInSession=0, lastName='Jackson', length=248.18893, level='free', location='Wichita, KS', method='PUT', page='NextSong', registration=1498489343284, sessionId=4404, song='Vibrator', status=200, ts=1513722006284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='481', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=5, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=2941, song=None, status=200, ts=1513722009284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist='LeAnn Rimes', auth='Logged In', firstName='Justin', gender='M', itemInSession=89, lastName='Jones', length=177.37098, level='paid', location='Dayton, TN', method='PUT', page='NextSong', registration=1504706730284, sessionId=1175, song="Nothin' Bout Love Makes Sense", status=200, ts=1513722016284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1176', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Kings Of Leon', auth='Logged In', firstName='Abigail', gender='F', itemInSession=8, lastName='Davidson', length=204.2771, level='paid', location='Lansing-East Lansing, MI', method='PUT', page='NextSong', registration=1513173389284, sessionId=4591, song='Manhattan', status=200, ts=1513722052284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"', userId='226', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Jeri Southern', auth='Logged In', firstName='Eliana', gender='F', itemInSession=5, lastName='Thomas', length=228.12689, level='paid', location='Knoxville, TN', method='PUT', page='NextSong', registration=1511496362284, sessionId=4686, song='Crazy He Calls Me', status=200, ts=1513722058284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2779', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Red Hot Chili Peppers', auth='Logged In', firstName='Gabriel', gender='M', itemInSession=6, lastName='Koch', length=321.82812, level='paid', location='Panama City, FL', method='PUT', page='NextSong', registration=1505820418284, sessionId=1060, song='Californication (Album Version)', status=200, ts=1513722080284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0', userId='1061', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Michael Jackson', auth='Logged In', firstName='Connor', gender='M', itemInSession=23, lastName='Gillespie', length=168.17587, level='paid', location='Santa Cruz-Watsonville, CA', method='PUT', page='NextSong', registration=1506639389284, sessionId=5698, song="Don't Let It Get You Down", status=200, ts=1513722089284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1035', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Slum Village', auth='Logged In', firstName='Joshua', gender='M', itemInSession=47, lastName='Blake', length=184.11057, level='paid', location='Fayetteville-Springdale-Rogers, AR-MO', method='PUT', page='NextSong', registration=1512526653284, sessionId=5340, song='Conant Gardens', status=200, ts=1513722102284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1949', userId_digit='1'),
#  Row(_corrupt_record=None, artist='The Mars Volta', auth='Logged In', firstName='Micheal', gender='M', itemInSession=28, lastName='Morgan', length=380.42077, level='paid', location='Sterling, CO', method='PUT', page='NextSong', registration=1485051492284, sessionId=5175, song='Eriatarka', status=200, ts=1513722105284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1806', userId_digit='1'),
#  Row(_corrupt_record=None, artist='LU', auth='Logged In', firstName='Vera', gender='F', itemInSession=11, lastName='Blackwell', length=321.54077, level='paid', location='Racine, WI', method='PUT', page='NextSong', registration=1499855749284, sessionId=5516, song='Una Confusion', status=200, ts=1513722128284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"', userId='2219', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Justin Timberlake', auth='Logged In', firstName='Kara', gender='F', itemInSession=0, lastName='Smith', length=355.99628, level='free', location='Atlanta-Sandy Springs-Roswell, GA', method='PUT', page='NextSong', registration=1508946027284, sessionId=5659, song='LoveStoned/I Think She Knows', status=200, ts=1513722153284, userAgent='Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0', userId='184', userId_digit='1'),
#  Row(_corrupt_record=None, artist='G. Love & Special Sauce', auth='Logged In', firstName='Sophee', gender='F', itemInSession=12, lastName='Barker', length=263.65342, level='paid', location='San Luis Obispo-Paso Robles-Arroyo Grande, CA', method='PUT', page='NextSong', registration=1513009647284, sessionId=2372, song='Numbers', status=200, ts=1513722156284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2373', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Jimmy Eat World', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=118, lastName='Matthews', length=213.99465, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='Seventeen', status=200, ts=1513722161284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Mya', gender='F', itemInSession=0, lastName='Garcia', length=None, level='free', location='New York-Newark-Jersey City, NY-NJ-PA', method='GET', page='Home', registration=1494444664284, sessionId=5282, song=None, status=200, ts=1513722170284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='2902', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Washed Out', auth='Logged In', firstName='Mason', gender='M', itemInSession=8, lastName='Thomas', length=192.07791, level='paid', location='Indianapolis-Carmel-Anderson, IN', method='PUT', page='NextSong', registration=1487015656284, sessionId=5661, song='Feel It All Around', status=200, ts=1513722182284, userAgent='Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)', userId='748', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Stryper', auth='Logged In', firstName='Zoie', gender='F', itemInSession=33, lastName='Wright', length=246.62159, level='paid', location='Chicago-Naperville-Elgin, IL-IN-WI', method='PUT', page='NextSong', registration=1512172030284, sessionId=2163, song='To Hell With The Devil', status=200, ts=1513722188284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2164', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Weezer', auth='Logged In', firstName='Justin', gender='M', itemInSession=90, lastName='Jones', length=258.82077, level='paid', location='Dayton, TN', method='PUT', page='NextSong', registration=1504706730284, sessionId=1175, song="Say It Ain't So", status=200, ts=1513722193284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1176', userId_digit='1'),
# ...
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Ashton', gender='M', itemInSession=31, lastName='Nelson', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='GET', page='Help', registration=1510608931284, sessionId=511, song=None, status=200, ts=1513735670284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0', userId='512', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Hanne Hukkelberg', auth='Logged In', firstName='Santiago', gender='M', itemInSession=12, lastName='Ford', length=264.80281, level='paid', location='New York-Newark-Jersey City, NY-NJ-PA', method='PUT', page='NextSong', registration=1505633879284, sessionId=2773, song='Bandy Riddles', status=200, ts=1513735687284, userAgent='"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='2774', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Coldplay', auth='Logged In', firstName='Ashton', gender='M', itemInSession=32, lastName='Nelson', length=298.762, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1510608931284, sessionId=511, song='Shiver', status=200, ts=1513735775284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0', userId='512', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Four Tops', auth='Logged In', firstName='Andrew', gender='M', itemInSession=28, lastName='Randall', length=206.86322, level='paid', location='Miami-Fort Lauderdale-West Palm Beach, FL', method='PUT', page='NextSong', registration=1509038679284, sessionId=5478, song='The Fool On The Hill', status=200, ts=1513735781284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='2867', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Five Iron Frenzy', auth='Logged In', firstName='Kaileigh', gender='F', itemInSession=2, lastName='Perkins', length=236.09424, level='free', location='Orlando-Kissimmee-Sanford, FL', method='PUT', page='NextSong', registration=1509561569284, sessionId=1076, song='Canada', status=200, ts=1513735782284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.102 Safari/537.36"', userId='1077', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Creedence Clearwater Revival', auth='Logged In', firstName='Jakobi', gender='M', itemInSession=25, lastName='Keller', length=271.882, level='paid', location='Kingston, NY', method='PUT', page='NextSong', registration=1494799164284, sessionId=4992, song='I Put A Spell On You', status=200, ts=1513735807284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_5) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/6.1.6 Safari/537.78.2"', userId='420', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Ratatat', auth='Logged In', firstName='Mason', gender='M', itemInSession=63, lastName='Thomas', length=276.79302, level='paid', location='Indianapolis-Carmel-Anderson, IN', method='PUT', page='NextSong', registration=1487015656284, sessionId=5661, song='Tropicana', status=200, ts=1513735813284, userAgent='Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)', userId='748', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Les Ogres De Barback', auth='Logged In', firstName='Damont', gender='M', itemInSession=22, lastName='Hardy', length=233.92608, level='paid', location='New York-Newark-Jersey City, NY-NJ-PA', method='PUT', page='NextSong', registration=1502341283284, sessionId=1208, song='Moi je', status=200, ts=1513735815284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko', userId='1209', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Tom Petty', auth='Logged In', firstName='Zoie', gender='F', itemInSession=94, lastName='Wright', length=186.87955, level='paid', location='Chicago-Naperville-Elgin, IL-IN-WI', method='PUT', page='NextSong', registration=1512172030284, sessionId=2163, song='Yer So Bad', status=200, ts=1513735859284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2164', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Enrique', gender='M', itemInSession=0, lastName='Miller', length=None, level='paid', location='Chicago-Naperville-Elgin, IL-IN-WI', method='GET', page='Home', registration=1500182660284, sessionId=5641, song=None, status=200, ts=1513735926284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='58', userId_digit='1'),
#  Row(_corrupt_record=None, artist='The Black Keys', auth='Logged In', firstName='Jordan', gender='M', itemInSession=36, lastName='Crosby', length=260.44036, level='paid', location='Columbus, GA-AL', method='PUT', page='NextSong', registration=1508616912284, sessionId=5764, song='Strange Desire', status=200, ts=1513735926284, userAgent='Mozilla/5.0 (Windows NT 6.1; Trident/7.0; rv:11.0) like Gecko', userId='2892', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Kimya Dawson', auth='Logged In', firstName='Santiago', gender='M', itemInSession=13, lastName='Ford', length=191.52934, level='paid', location='New York-Newark-Jersey City, NY-NJ-PA', method='PUT', page='NextSong', registration=1505633879284, sessionId=2773, song='The Beer', status=200, ts=1513735951284, userAgent='"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='2774', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Santiago', gender='M', itemInSession=14, lastName='Ford', length=None, level='paid', location='New York-Newark-Jersey City, NY-NJ-PA', method='PUT', page='Logout', registration=1505633879284, sessionId=2773, song=None, status=307, ts=1513735952284, userAgent='"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='2774', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Kanye West', auth='Logged In', firstName='Enrique', gender='M', itemInSession=1, lastName='Miller', length=230.53016, level='paid', location='Chicago-Naperville-Elgin, IL-IN-WI', method='PUT', page='NextSong', registration=1500182660284, sessionId=5641, song='Late', status=200, ts=1513735954284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='58', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=15, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=2773, song=None, status=200, ts=1513735959284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist='Daughtry', auth='Logged In', firstName='Jaelyn', gender='F', itemInSession=26, lastName='Wilson', length=249.91302, level='paid', location='Lexington-Fayette, KY', method='PUT', page='NextSong', registration=1508581556284, sessionId=3146, song='No Surprise', status=200, ts=1513735962284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1955', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=16, lastName=None, length=None, level='paid', location=None, method='GET', page='About', registration=None, sessionId=2773, song=None, status=200, ts=1513735976284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist='Joe Bonamassa', auth='Logged In', firstName='Andrew', gender='M', itemInSession=29, lastName='Randall', length=439.66649, level='paid', location='Miami-Fort Lauderdale-West Palm Beach, FL', method='PUT', page='NextSong', registration=1509038679284, sessionId=5478, song='Blues Deluxe', status=200, ts=1513735987284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='2867', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Jill Scott', auth='Logged In', firstName='Rashaan', gender='M', itemInSession=0, lastName='Allen', length=209.68444, level='free', location='Seattle-Tacoma-Bellevue, WA', method='PUT', page='NextSong', registration=1496186310284, sessionId=5739, song='Hate On Me', status=200, ts=1513736013284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2593', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Lucybell', auth='Logged In', firstName='Kaileigh', gender='F', itemInSession=3, lastName='Perkins', length=223.00689, level='free', location='Orlando-Kissimmee-Sanford, FL', method='PUT', page='NextSong', registration=1509561569284, sessionId=1076, song='Juego De Seduccion', status=200, ts=1513736018284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.102 Safari/537.36"', userId='1077', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Enya', auth='Logged In', firstName='Kelly', gender='F', itemInSession=29, lastName='Newton', length=197.66812, level='paid', location='Houston-The Woodlands-Sugar Land, TX', method='PUT', page='NextSong', registration=1513283366284, sessionId=5566, song='March Of The Celts', status=200, ts=1513736040284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='1138', userId_digit='1'),
#  Row(_corrupt_record=None, artist='P J Harvey', auth='Logged In', firstName='Zoie', gender='F', itemInSession=95, lastName='Wright', length=198.29506, level='paid', location='Chicago-Naperville-Elgin, IL-IN-WI', method='PUT', page='NextSong', registration=1512172030284, sessionId=2163, song='Dress', status=200, ts=1513736045284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2164', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Metallica', auth='Logged In', firstName='Damont', gender='M', itemInSession=23, lastName='Hardy', length=267.96363, level='paid', location='New York-Newark-Jersey City, NY-NJ-PA', method='PUT', page='NextSong', registration=1502341283284, sessionId=1208, song='Until It Sleeps', status=200, ts=1513736048284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko', userId='1209', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Limp Bizkit', auth='Logged In', firstName='Autumn', gender='F', itemInSession=0, lastName='Alexander', length=214.5171, level='free', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1512248625284, sessionId=4629, song="Rollin' (Air Raid Vehicle)", status=200, ts=1513736059284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10) AppleWebKit/600.1.8 (KHTML, like Gecko) Version/8.0 Safari/600.1.8"', userId='745', userId_digit='1'),
#  Row(_corrupt_record=None, artist='The Four Seasons', auth='Logged In', firstName='Ashton', gender='M', itemInSession=33, lastName='Nelson', length=279.01342, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1510608931284, sessionId=511, song="Medley: Stay/Let's Hang On/Opus 17 [Don't You Worry 'Bout Me/Bye_ Bye_ Baby]", status=200, ts=1513736073284, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0', userId='512', userId_digit='1'),
#  Row(_corrupt_record=None, artist='NOFX', auth='Logged In', firstName='Jakobi', gender='M', itemInSession=26, lastName='Keller', length=108.09424, level='paid', location='Kingston, NY', method='PUT', page='NextSong', registration=1494799164284, sessionId=4992, song='Fleas', status=200, ts=1513736078284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_5) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/6.1.6 Safari/537.78.2"', userId='420', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=17, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=2773, song=None, status=200, ts=1513736082284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist='Conjure One', auth='Logged In', firstName='Enrique', gender='M', itemInSession=2, lastName='Miller', length=419.26485, level='paid', location='Chicago-Naperville-Elgin, IL-IN-WI', method='PUT', page='NextSong', registration=1500182660284, sessionId=5641, song='Redemption', status=200, ts=1513736184284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='58', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Mason', auth='Logged In', firstName='Jordan', gender='M', itemInSession=37, lastName='Crosby', length=405.2371, level='paid', location='Columbus, GA-AL', method='PUT', page='NextSong', registration=1508616912284, sessionId=5764, song='Exceeder', status=200, ts=1513736186284, userAgent='Mozilla/5.0 (Windows NT 6.1; Trident/7.0; rv:11.0) like Gecko', userId='2892', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Bloodhound Gang', auth='Logged In', firstName='Jakobi', gender='M', itemInSession=27, lastName='Keller', length=184.78975, level='paid', location='Kingston, NY', method='PUT', page='NextSong', registration=1494799164284, sessionId=4992, song='Kiss Me Where It Smells Funny', status=200, ts=1513736186284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_5) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/6.1.6 Safari/537.78.2"', userId='420', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Jakobi', gender='M', itemInSession=28, lastName='Keller', length=None, level='paid', location='Kingston, NY', method='PUT', page='Logout', registration=1494799164284, sessionId=4992, song=None, status=307, ts=1513736187284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_5) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/6.1.6 Safari/537.78.2"', userId='420', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Akercocke', auth='Logged In', firstName='Jaelyn', gender='F', itemInSession=27, lastName='Wilson', length=272.24771, level='paid', location='Lexington-Fayette, KY', method='PUT', page='NextSong', registration=1508581556284, sessionId=3146, song='The Penance', status=200, ts=1513736211284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1955', userId_digit='1'),
#  Row(_corrupt_record=None, artist=None, auth='Logged In', firstName='Leonides', gender='M', itemInSession=0, lastName='Moore', length=None, level='free', location='Morehead City, NC', method='GET', page='Home', registration=1507321335284, sessionId=5611, song=None, status=200, ts=1513736221284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2743', userId_digit='1'),
#  Row(_corrupt_record=None, artist='Stacie Orrico', auth='Logged In', firstName='Rashaan', gender='M', itemInSession=1, lastName='Allen', length=237.92281, level='free', location='Seattle-Tacoma-Bellevue, WA', method='PUT', page='NextSong', registration=1496186310284, sessionId=5739, song='Strong Enough', status=200, ts=1513736222284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2593', userId_digit='1'),
#  ...]

# %% [markdown]
# Now we can see the addition of the ```userId_digit``` column

# %%
incorrect_records.value
# Out:
# 336

# %% [markdown]
# Let's see what some of these incorrect records look like:

# %%
logs.filter(logs["userId_digit"].isNull()).collect()
# Out:
# [Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5598, song=None, status=307, ts=1513721196284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=26, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=428, song=None, status=200, ts=1513721274284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=5, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=2941, song=None, status=200, ts=1513722009284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=5, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5243, song=None, status=200, ts=1513723183284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=6, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=5243, song=None, status=307, ts=1513723184284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=1477, song=None, status=307, ts=1513723587284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=14, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5243, song=None, status=200, ts=1513724475284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=7, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=4108, song=None, status=200, ts=1513724530284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=5764, song=None, status=307, ts=1513728229284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5566, song=None, status=200, ts=1513729051284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=5566, song=None, status=307, ts=1513729052284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=3697, song=None, status=200, ts=1513729376284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='paid', location=None, method='GET', page='Help', registration=None, sessionId=3697, song=None, status=200, ts=1513729445284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=60, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5175, song=None, status=200, ts=1513729762284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=61, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=5175, song=None, status=307, ts=1513729763284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=511, song=None, status=200, ts=1513730128284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=511, song=None, status=307, ts=1513730129284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=2992, song=None, status=200, ts=1513730621284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=2992, song=None, status=307, ts=1513730622284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=8, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=4239, song=None, status=200, ts=1513730953284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=9, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=4239, song=None, status=307, ts=1513730954284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=2, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=4441, song=None, status=200, ts=1513731045284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='GET', page='About', registration=None, sessionId=4441, song=None, status=200, ts=1513731065284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=925, song=None, status=307, ts=1513731101284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=2, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5817, song=None, status=200, ts=1513731277284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5817, song=None, status=307, ts=1513731278284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=4934, song=None, status=200, ts=1513731834284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=4934, song=None, status=307, ts=1513731835284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=184, song=None, status=200, ts=1513733637284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=2203, song=None, status=307, ts=1513734694284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=1839, song=None, status=200, ts=1513734883284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=15, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=2773, song=None, status=200, ts=1513735959284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=16, lastName=None, length=None, level='paid', location=None, method='GET', page='About', registration=None, sessionId=2773, song=None, status=200, ts=1513735976284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=17, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=2773, song=None, status=200, ts=1513736082284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=29, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=4992, song=None, status=200, ts=1513736560284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=185, song=None, status=200, ts=1513737804284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='GET', page='About', registration=None, sessionId=185, song=None, status=200, ts=1513737827284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=42, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=3146, song=None, status=200, ts=1513738847284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=43, lastName=None, length=None, level='paid', location=None, method='GET', page='About', registration=None, sessionId=3146, song=None, status=200, ts=1513738848284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=8, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=1064, song=None, status=200, ts=1513741997284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=5, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=2993, song=None, status=200, ts=1513742384284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=6, lastName=None, length=None, level='free', location=None, method='GET', page='Help', registration=None, sessionId=2993, song=None, status=200, ts=1513742425284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=7, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=2993, song=None, status=200, ts=1513742458284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=8, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=2993, song=None, status=307, ts=1513742459284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=57, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5478, song=None, status=200, ts=1513742804284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=4, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5826, song=None, status=200, ts=1513743807284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=5, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5826, song=None, status=307, ts=1513743808284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=20, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=1985, song=None, status=200, ts=1513745516284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=21, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=1985, song=None, status=307, ts=1513745517284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=3951, song=None, status=200, ts=1513745727284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=2, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5552, song=None, status=200, ts=1513746313284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5552, song=None, status=307, ts=1513746314284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5053, song=None, status=200, ts=1513746331284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='GET', page='About', registration=None, sessionId=5053, song=None, status=200, ts=1513746352284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=2, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5053, song=None, status=200, ts=1513746353284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5053, song=None, status=307, ts=1513746354284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=3951, song=None, status=200, ts=1513746544284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=2, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=3951, song=None, status=200, ts=1513746594284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=4904, song=None, status=200, ts=1513746674284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='paid', location=None, method='GET', page='About', registration=None, sessionId=3951, song=None, status=200, ts=1513746827284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=4, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=3951, song=None, status=307, ts=1513746828284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=8, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5552, song=None, status=200, ts=1513747001284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=9, lastName=None, length=None, level='free', location=None, method='GET', page='About', registration=None, sessionId=5552, song=None, status=200, ts=1513747258284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=10, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5552, song=None, status=200, ts=1513747529284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=11, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=3951, song=None, status=200, ts=1513748217284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=12, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=3951, song=None, status=307, ts=1513748218284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=5777, song=None, status=307, ts=1513750117284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=44, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=1985, song=None, status=200, ts=1513750618284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=2075, song=None, status=200, ts=1513750875284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=2075, song=None, status=307, ts=1513750876284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=4756, song=None, status=200, ts=1513751234284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=4756, song=None, status=307, ts=1513751235284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=42, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5915, song=None, status=200, ts=1513751311284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=19, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=4964, song=None, status=200, ts=1513751450284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=20, lastName=None, length=None, level='paid', location=None, method='GET', page='Help', registration=None, sessionId=4964, song=None, status=200, ts=1513751482284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=265, song=None, status=307, ts=1513755459284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=7, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5219, song=None, status=200, ts=1513757589284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=8, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5219, song=None, status=307, ts=1513757590284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=5809, song=None, status=307, ts=1513757740284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=806, song=None, status=200, ts=1513757790284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=2, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5848, song=None, status=200, ts=1513758729284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=1967, song=None, status=200, ts=1513760099284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=1967, song=None, status=307, ts=1513760100284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=2, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=4333, song=None, status=200, ts=1513760813284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=4333, song=None, status=307, ts=1513760814284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=2, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5833, song=None, status=200, ts=1513762196284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=5833, song=None, status=307, ts=1513762197284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=4845, song=None, status=307, ts=1513762637284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=64, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=1078, song=None, status=200, ts=1513763025284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=65, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=1078, song=None, status=307, ts=1513763026284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=4937, song=None, status=200, ts=1513763662284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='paid', location=None, method='GET', page='About', registration=None, sessionId=4937, song=None, status=200, ts=1513763734284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=2, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=4937, song=None, status=200, ts=1513763741284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=1392, song=None, status=200, ts=1513764034284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=2112, song=None, status=200, ts=1513764513284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=2112, song=None, status=307, ts=1513764514284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5866, song=None, status=200, ts=1513764939284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5866, song=None, status=307, ts=1513764940284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=6021, song=None, status=200, ts=1513766304284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=6021, song=None, status=307, ts=1513766305284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=4, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=2003, song=None, status=200, ts=1513767000284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=5, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=2003, song=None, status=307, ts=1513767001284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=2, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5993, song=None, status=200, ts=1513769591284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5993, song=None, status=307, ts=1513769592284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=4204, song=None, status=200, ts=1513770311284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='GET', page='About', registration=None, sessionId=4204, song=None, status=200, ts=1513770351284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=2, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=281, song=None, status=200, ts=1513770563284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=281, song=None, status=307, ts=1513770564284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=10, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=173, song=None, status=200, ts=1513771013284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5278, song=None, status=307, ts=1513771051284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=25, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=4596, song=None, status=200, ts=1513771072284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=485, song=None, status=307, ts=1513771398284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=1925, song=None, status=200, ts=1513772841284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=1925, song=None, status=307, ts=1513772842284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=1827, song=None, status=200, ts=1513774089284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=4, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=1827, song=None, status=307, ts=1513774090284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=2731, song=None, status=307, ts=1513774380284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=5724, song=None, status=307, ts=1513774700284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5665, song=None, status=307, ts=1513774997284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=910, song=None, status=200, ts=1513775107284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=5, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=1384, song=None, status=200, ts=1513775108284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5256, song=None, status=200, ts=1513775164284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=2695, song=None, status=200, ts=1513775364284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=2695, song=None, status=307, ts=1513775365284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5644, song=None, status=200, ts=1513775858284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=3784, song=None, status=200, ts=1513775942284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=28, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=4496, song=None, status=200, ts=1513776079284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=29, lastName=None, length=None, level='paid', location=None, method='GET', page='Help', registration=None, sessionId=4496, song=None, status=200, ts=1513776083284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=4894, song=None, status=307, ts=1513776318284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=116, song=None, status=200, ts=1513776651284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=116, song=None, status=307, ts=1513776652284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=5, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=4868, song=None, status=200, ts=1513777279284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=7, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5932, song=None, status=200, ts=1513777486284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5319, song=None, status=200, ts=1513777617284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=4, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5319, song=None, status=307, ts=1513777618284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=6, lastName=None, length=None, level='free', location=None, method='GET', page='About', registration=None, sessionId=4868, song=None, status=200, ts=1513777626284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=2552, song=None, status=307, ts=1513778035284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=845, song=None, status=200, ts=1513778146284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=15, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5724, song=None, status=200, ts=1513778395284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5364, song=None, status=200, ts=1513778431284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=6009, song=None, status=200, ts=1513779396284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=4, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=6009, song=None, status=307, ts=1513779397284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=34, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=2293, song=None, status=200, ts=1513779748284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=35, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=2293, song=None, status=200, ts=1513779863284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=3509, song=None, status=307, ts=1513779878284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5345, song=None, status=200, ts=1513779933284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=36, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=2293, song=None, status=200, ts=1513780092284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=37, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=2293, song=None, status=307, ts=1513780093284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=3815, song=None, status=307, ts=1513780225284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=2, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5945, song=None, status=200, ts=1513780261284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5945, song=None, status=307, ts=1513780262284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=3815, song=None, status=200, ts=1513780420284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=41, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=485, song=None, status=200, ts=1513780570284, userAgent=None, userId='', userId_digit=None),
# ...
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5221, song=None, status=200, ts=1513829956284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=5221, song=None, status=307, ts=1513829957284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=58, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=6878, song=None, status=200, ts=1513830380284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=18, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=6767, song=None, status=200, ts=1513830655284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=5, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=6245, song=None, status=200, ts=1513831585284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=6, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=6245, song=None, status=200, ts=1513831714284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=5, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5992, song=None, status=200, ts=1513831850284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=6, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5992, song=None, status=307, ts=1513831851284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=2602, song=None, status=200, ts=1513832509284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=2602, song=None, status=307, ts=1513832510284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5767, song=None, status=200, ts=1513834216284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5767, song=None, status=307, ts=1513834217284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=6232, song=None, status=307, ts=1513834853284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5978, song=None, status=200, ts=1513835587284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5176, song=None, status=200, ts=1513835945284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=4, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5176, song=None, status=200, ts=1513835948284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=5, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5176, song=None, status=307, ts=1513835949284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=10, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=6391, song=None, status=200, ts=1513836104284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=5623, song=None, status=307, ts=1513837488284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=5, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5786, song=None, status=200, ts=1513838110284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=6, lastName=None, length=None, level='paid', location=None, method='GET', page='About', registration=None, sessionId=5786, song=None, status=200, ts=1513838121284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=7, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5786, song=None, status=200, ts=1513838141284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=8, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=5786, song=None, status=307, ts=1513838142284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=5900, song=None, status=200, ts=1513838835284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=5900, song=None, status=307, ts=1513838836284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=4824, song=None, status=200, ts=1513838857284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=4824, song=None, status=200, ts=1513838865284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=2, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=4824, song=None, status=307, ts=1513838866284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=6951, song=None, status=200, ts=1513839824284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=2019, song=None, status=200, ts=1513841121284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=1, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=2019, song=None, status=307, ts=1513841122284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=14, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=7016, song=None, status=200, ts=1513841138284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=15, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=7016, song=None, status=307, ts=1513841139284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=7096, song=None, status=307, ts=1513841355284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=45, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5431, song=None, status=200, ts=1513842367284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=46, lastName=None, length=None, level='paid', location=None, method='PUT', page='Login', registration=None, sessionId=5431, song=None, status=307, ts=1513842368284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=6667, song=None, status=307, ts=1513842373284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=4847, song=None, status=200, ts=1513843098284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=4, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=4847, song=None, status=200, ts=1513843602284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=5, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=3421, song=None, status=200, ts=1513844026284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=6, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=3421, song=None, status=307, ts=1513844027284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=5, lastName=None, length=None, level='free', location=None, method='GET', page='About', registration=None, sessionId=4847, song=None, status=200, ts=1513844116284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=6, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=4847, song=None, status=200, ts=1513844251284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=7, lastName=None, length=None, level='free', location=None, method='GET', page='About', registration=None, sessionId=4847, song=None, status=200, ts=1513844295284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=8, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=4847, song=None, status=307, ts=1513844296284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=3, lastName=None, length=None, level='free', location=None, method='GET', page='Home', registration=None, sessionId=1367, song=None, status=200, ts=1513845055284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=4, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=1367, song=None, status=307, ts=1513845056284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=37, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=5623, song=None, status=200, ts=1513845132284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=26, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=6890, song=None, status=200, ts=1513845761284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='free', location=None, method='PUT', page='Login', registration=None, sessionId=2966, song=None, status=307, ts=1513845905284, userAgent=None, userId='', userId_digit=None),
#  Row(_corrupt_record=None, artist=None, auth='Logged Out', firstName=None, gender=None, itemInSession=0, lastName=None, length=None, level='paid', location=None, method='GET', page='Home', registration=None, sessionId=7064, song=None, status=200, ts=1513846494284, userAgent=None, userId='', userId_digit=None)]

# %% [markdown]
# We can see that for much of these records, the userId is an empty string value, definitely not any digit.

# %%
incorrect_records.value
# Out:
# 1008

# %% [markdown]
# Now the value of the accumulator is 1008, compared to 336 previously. This is due to the above statement ```logs.filter(logs["userId_digit"].isNull()).collect()```, where collect() was called again and the accumulator was further incremented.
